# %%
import vis_keras as vk
# Out:
# Using TensorFlow backend.

# %%
explorer = vk.Model_explorer('models/s126_k9_f9_b16_e4.h5')

# %%
explorer.set_test_image('OASIS/Test/predict/normal.png')
# Out:
# {'name': 'PIL.PngImagePlugin', 'msg': 'STREAM %s %s %s', 'args': (b'IHDR', 16, 13), 'levelname': 'DEBUG', 'levelno': 10, 'pathname': '/home/jakob/anaconda3/lib/python3.6/site-packages/PIL/PngImagePlugin.py', 'filename': 'PngImagePlugin.py', 'module': 'PngImagePlugin', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 135, 'funcName': 'call', 'created': 1526408928.5509682, 'msecs': 550.9681701660156, 'relativeCreated': 188699.72252845764, 'thread': 139932094199552, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 3170, 'message': "STREAM b'IHDR' 16 13"}
# ...

# %%
explorer.activations()

# %%
explorer.cam()

# %%
### Filters of the first layer

# %%
explorer.filters()

# %%
explorer.grad_ascent()
# Out:
# Current loss value:0.000 , filter: 1 break
# Current loss value:0.000 , filter: 3 break
# Current loss value:0.000 , filter: 5 break
# Current loss value:0.000 , filter: 8 break
# Current loss value:0.000 , filter: 10 break
# Current loss value:0.000 , filter: 13 break
# Current loss value:0.000 , filter: 15 break
# Current loss value:0.000 , filter: 17 break
# Current loss value:0.000 , filter: 20 break
# Current loss value:0.000 , filter: 23 break
# Current loss value:0.000 , filter: 25 break
# Current loss value:0.000 , filter: 30 break
# Current loss value:0.000 , filter: 32 break
# Current loss value:0.000 , filter: 33 break
# Current loss value:0.000 , filter: 35 break
# Current loss value:0.000 , filter: 36 break
# Current loss value:0.000 , filter: 37 break
# Current loss value:0.000 , filter: 41 break
# Current loss value:0.000 , filter: 42 break
# Current loss value:0.000 , filter: 43 break
# Current loss value:0.000 , filter: 46 break
# ...
